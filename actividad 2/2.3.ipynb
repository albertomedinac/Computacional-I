# %%
# Cargar a la memoria de trabajo las bibliotecas: Pandas (manejo de datos, 
# Numpy (numerical python) y la biblioteca de gráficas Matplotlib
# Se asignan nombres cortos.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#
# Usar "Shift+Enter" para procesar la información de la celda
#

# %%
# Descarga los datos de una estación del Servicio Meteorológico Nacional
# http://smn1.conagua.gob.mx/emas/
# Lee un archivo de texto con la función Pandas "read_csv", con elementos separados por mas de 
# un espacio, brincándose 4 renglones del inicio (encabezados)
df0 = pd.read_csv('nogales2.txt', skiprows=0, sep='\s+')
# "Shift + Enter"

# %%
df0
# Out:
#      DD/MM/AAAA  HH:MM   DIRS   DIRR   VELS  VELR  TEMP    HR     PB  PREC  \
# 0    26/01/2019  17:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 1    26/01/2019  18:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 2    26/01/2019  19:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 3    26/01/2019  20:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 4    26/01/2019  21:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 5    26/01/2019  22:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 6    26/01/2019  23:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 7    27/01/2019  00:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 8    27/01/2019  01:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 9    27/01/2019  02:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# 10   27/01/2019  03:00    NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN
# ...

# %%
# Dar estructura de datos (DataFrame)
df = pd.DataFrame(df0)

# %%
# Ver los tipos de datos que Pandas ha reconocido al leer
df.dtypes
# Out:
# DD/MM/AAAA     object
# HH:MM          object
# DIRS          float64
# DIRR          float64
# VELS          float64
# VELR          float64
# TEMP          float64
# HR            float64
# PB            float64
# PREC          float64
# RADSOL        float64
# dtype: object

# %%
# Combinar las columnas "DD/MM/AAAA" con "HH:MM" y convertirla a variable de tiempo
# Se crea una nueva columna "Fecha" al final con formato de tiempo.
# Eliminamos las dos primeras columnas que ya no necesitaremos
df['FECHA'] = pd.to_datetime(df.apply(lambda x: x['DD/MM/AAAA'] + ' ' + x['HH:MM'], 1), dayfirst=True)
df = df.drop(['DD/MM/AAAA', 'HH:MM'], 1)

# %%
df
# Out:
#       DIRS   DIRR   VELS  VELR  TEMP    HR     PB  PREC  RADSOL  \
# 0      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 1      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 2      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 3      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 4      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 5      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 6      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 7      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 8      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 9      NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 10     NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 11     NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 12     NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# 13     NaN    NaN    NaN   NaN   NaN   NaN    NaN   NaN     NaN
# ...

# %%
# Realiza un análisis exploratorio de datos
df.describe()
# Out:
#              DIRS        DIRR        VELS        VELR        TEMP          HR  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000  108.000000
# mean   223.444444  245.222222    6.222778   14.861111   13.951852   37.194444
# std     81.126800   78.603267    4.123645    8.124612    4.687316   11.615699
# min      5.000000   20.000000    0.420000    4.400000    5.600000   14.000000
# 25%    195.250000  218.750000    2.597500    8.000000    9.800000   29.750000
# 50%    240.000000  259.500000    5.190000   11.900000   13.800000   38.000000
# 75%    273.500000  304.500000    9.075000   21.025000   17.725000   45.000000
# max    359.000000  360.000000   16.810000   32.400000   23.800000   63.000000
#
#                PB   PREC      RADSOL
# count  108.000000  108.0  108.000000
# mean   872.309259    0.0  162.482407
# std      1.234514    0.0  242.399183
# min    869.900000    0.0    0.000000
# 25%    871.575000    0.0    0.000000
# 50%    872.450000    0.0    0.000000
# ...

# %%
# Selecciona los renglones con Temperatura > 5ºC y < 6ºC
df_tmp = df[df.TEMP > 5] 
df_select = df_tmp[df_tmp.TEMP < 6]
df_select
# Out:
#      DIRS   DIRR  VELS  VELR  TEMP    HR     PB  PREC  RADSOL  \
# 44  324.0   96.0  2.43   6.1   5.6  44.0  872.6   0.0     0.0
# 45  306.0  304.0  0.82   5.0   5.9  44.0  873.1   0.0    20.7
#
#                  FECHA
# 44 2019-01-28 13:00:00
# 45 2019-01-28 14:00:00

# %%
# Calcula el promedio de las columnas, excepto en la FECHA (que no tendría sentido)
df.mean()
# Out:
# DIRS      223.444444
# DIRR      245.222222
# VELS        6.222778
# VELR       14.861111
# TEMP       13.951852
# HR         37.194444
# PB        872.309259
# PREC        0.000000
# RADSOL    162.482407
# dtype: float64

# %%
# Calcula el promedio de las Temperaturas
df.TEMP.mean()
# Out:
# 13.95185185185185

# %%
# Gráfica de velocidades
df1 = df[['VELS','VELR']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("Variación de la Velocidad")
plt.ylabel("Velocidad (m/s)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### La hora en que hace mas viento es por la tarde, a las 8 pm

# %%
# Gráfica de Direccion del viento
df1 = df[['DIRS','DIRR']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("Variación de la direccion del viento")
plt.ylabel("Direccion")
plt.grid(True)
plt.show()

# %%
# Gráfica del comportamiento de la radiación solar 
plt.figure(); df.RADSOL.plot(); plt.legend(loc='best')
plt.title("Variación de la radiación solar")
plt.ylabel("Radiación (W/m^2)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### En nogales hay picos de radiación a partir de las 7 de la tarde hasta la media noche.

# %%
# Gráfica de la temperatura 
plt.figure(); df.TEMP.plot(); plt.legend(loc='best')
plt.title("Variación de la Temperatura")
plt.ylabel("Temperatura (C)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### la diferencia entre la máxima y mínima temperatura en nogales es de: 18.2 grados

# %%
# Gráfica de Temperatura y Humedad Relativa
df1 = df[['TEMP','HR']]
plt.figure(); df1.plot(); plt.legend(loc='best')
plt.title("Variación de la Temperatura y la Humedad Relativa")
plt.ylabel("Temp ºC /(%) HR")
plt.grid(True)
plt.show()

# %% [markdown]
# ### como se observa cuando la humedad aumenta la temperatura disminuye y vicerversa.
