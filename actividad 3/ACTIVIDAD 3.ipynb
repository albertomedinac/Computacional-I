# %%
#importamos a panda
import pandas as pd
import numpy as np

# %%
#descargamos los datos
df=pd.read_csv('aguaprieta2',skiprows=20,skipfooter=1, sep='\s+',header=None,names=['DD/MM/YY','PRECIP','EVAP','TMAX','TMIN'],engine='python')

# %%
df
# Out:
#          DD/MM/YY  PRECIP  EVAP  TMAX  TMIN
# 0      01/02/1961     0.0   NaN  19.5   2.0
# 1      02/02/1961     0.0   NaN  20.0   2.5
# 2      03/02/1961     0.0   2.7  21.5   1.8
# 3      04/02/1961     0.0   3.0  16.7   1.0
# 4      05/02/1961     0.0   1.3  11.4   4.0
# 5      06/02/1961     0.0   1.8  12.4  -3.0
# 6      07/02/1961     0.0   1.0  14.8  -3.0
# 7      08/02/1961     0.0   3.3  18.4  -3.5
# 8      09/02/1961     0.0   3.2  19.8  -2.0
# 9      10/02/1961     0.0   3.2  24.0  -1.0
# 10     11/02/1961     0.0   3.2  26.8   0.5
# 11     12/02/1961     0.0   4.8  25.8   0.8
# 12     13/02/1961     0.0   4.3  26.5   3.5
# 13     14/02/1961     0.0   2.5  24.4   1.0
# 14     15/02/1961     0.0   4.1  25.0   0.8
# 15     16/02/1961     0.0   5.4  22.5   0.0
# 16     17/02/1961     0.0   2.9  17.8   0.5
# 17     18/02/1961     0.0   3.6  22.4  -2.8
# 18     19/02/1961     1.0   1.8  14.8   0.5
# 19     20/02/1961     0.0   3.2  15.8  -1.5
# ...

# %%
df.dtypes
# Out:
# DD/MM/YY     object
# PRECIP      float64
# EVAP        float64
# TMAX        float64
# TMIN        float64
# dtype: object

# %%
df['FECHA'] = pd.to_datetime(df.apply(lambda x: x['DD/MM/YY'], 1), dayfirst=True)
df=df.drop(['DD/MM/YY'],1)

# %%
df.dtypes
# Out:
# PRECIP           float64
# EVAP             float64
# TMAX             float64
# TMIN             float64
# FECHA     datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#    PRECIP  EVAP  TMAX  TMIN      FECHA
# 0     0.0   NaN  19.5   2.0 1961-02-01
# 1     0.0   NaN  20.0   2.5 1961-02-02
# 2     0.0   2.7  21.5   1.8 1961-02-03
# 3     0.0   3.0  16.7   1.0 1961-02-04
# 4     0.0   1.3  11.4   4.0 1961-02-05

# %%
df.tail()
# Out:
#        PRECIP  EVAP  TMAX  TMIN      FECHA
# 16747     0.0   6.4  36.0  20.0 2011-07-27
# 16748    13.0   6.2  37.0  20.0 2011-07-28
# 16749     0.0   4.2  36.0  20.0 2011-07-29
# 16750    11.0   1.7  35.0  20.0 2011-07-30
# 16751    13.0   NaN  34.0  21.0 2011-07-31

# %%
df.mean()
# Out:
# PRECIP     0.955698
# EVAP       5.679653
# TMAX      26.371555
# TMIN       8.596580
# dtype: float64
