# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('kino.dat')

# %%
df.dtypes
# Out:
# TIMESTAMP            object
# RECORD                int64
# batt_volt_Min       float64
# logger_temp         float64
# short_up_Avg        float64
# short_dn_Avg        float64
# long_up_Avg         float64
# long_dn_Avg         float64
# cnr4_T_C_Avg        float64
# cnr4_T_K_Avg        float64
# long_up_corr_Avg    float64
# long_dn_corr_Avg    float64
# Rs_net_Avg          float64
# Rl_net_Avg          float64
# albedo_Avg           object
# Rn_Avg              float64
# AirTC_Avg           float64
# RH                  float64
# WS_ms_S_WVT         float64
# WindDir_D1_WVT      float64
# WindDir_SD1_WVT     float64
# Temp_C_Avg(1)       float64
# Temp_C_Avg(2)       float64
# Temp_C_Avg(3)       float64
# Temp_C_Avg(4)        object
# Result1_Avg          object
# Result2_Avg         float64
# Result3_Avg         float64
# Result4_Avg         float64
# Result5_Avg         float64
# Result6_Avg         float64
# Result7_Avg         float64
# Result8_Avg         float64
# Result9_Avg         float64
# Riego_mm_Tot        float64
# Perco_mm_Tot          int64
# dtype: object

# %%
df['FECHA'] = pd.to_datetime(df.apply(lambda x: x['TIMESTAMP'], 1), dayfirst=True)
df = df.drop(['TIMESTAMP'], 1)

# %%
df.head()
# Out:
#    RECORD  batt_volt_Min  logger_temp  short_up_Avg  short_dn_Avg  \
# 0    7980          12.31        25.87     -5.499501      1.581859
# 1    7981          12.30        25.37     -4.934265      1.946161
# 2    7982          12.28        24.91     -4.615617      2.407313
# 3    7983          12.27        24.47     -4.433317      2.523456
# 4    7984          12.26        24.09     -2.861873      3.898805
#
#    long_up_Avg  long_dn_Avg  cnr4_T_C_Avg  cnr4_T_K_Avg  long_up_corr_Avg  \
# 0    -82.19471    -4.002829      23.26391      296.4139          355.5072
# 1    -80.00718    -1.978131      22.75189      295.9019          354.6775
# 2    -76.72183    -1.868207      22.43361      295.5836          356.0954
# 3    -73.10189    -3.367143      22.08901      295.2390          357.7008
# 4    -70.19295     0.915511      22.08449      295.2345          360.5843
#
#           ...          Result3_Avg  Result4_Avg  Result5_Avg Result6_Avg  \
# 0         ...                 26.4         79.5        0.041       14.71
# 1         ...                 26.4         79.5        0.041       14.71
# 2         ...                 26.4         79.5        0.041       14.71
# 3         ...                 26.4         79.5        0.041       14.71
# 4         ...                 26.4         79.5        0.041       14.70
#
#    Result7_Avg  Result8_Avg  Result9_Avg  Riego_mm_Tot  Perco_mm_Tot  \
# 0        14.75        15.09        14.45           0.0             0
# 1        14.75        15.09        14.45           0.0             0
# 2        14.75        15.09        14.46           0.0             0
# 3        14.75        15.09        14.45           0.0             0
# 4        14.76        15.08        14.46           0.0             0
#
#                 FECHA
# 0 2018-05-11 20:10:00
# 1 2018-05-11 20:20:00
# 2 2018-05-11 20:30:00
# 3 2018-05-11 20:40:00
# 4 2018-05-11 20:50:00
#
# [5 rows x 36 columns]

# %%
df['MES']=df['FECHA'].dt.month
df['SEG']=df['FECHA'].dt.second
df['DIA']=df['FECHA'].dt.day
df['MIN']=df['FECHA'].dt.minute
df['HORA']=df['FECHA'].dt.hour
df['AÑO']=df['FECHA'].dt.year

# %%
df['TEMP']=df['AirTC_Avg']
df.drop(['AirTC_Avg'],1)
df.head()
# Out:
#    RECORD  batt_volt_Min  logger_temp  short_up_Avg  short_dn_Avg  \
# 0    7980          12.31        25.87     -5.499501      1.581859
# 1    7981          12.30        25.37     -4.934265      1.946161
# 2    7982          12.28        24.91     -4.615617      2.407313
# 3    7983          12.27        24.47     -4.433317      2.523456
# 4    7984          12.26        24.09     -2.861873      3.898805
#
#    long_up_Avg  long_dn_Avg  cnr4_T_C_Avg  cnr4_T_K_Avg  long_up_corr_Avg  \
# 0    -82.19471    -4.002829      23.26391      296.4139          355.5072
# 1    -80.00718    -1.978131      22.75189      295.9019          354.6775
# 2    -76.72183    -1.868207      22.43361      295.5836          356.0954
# 3    -73.10189    -3.367143      22.08901      295.2390          357.7008
# 4    -70.19295     0.915511      22.08449      295.2345          360.5843
#
#    ...    Riego_mm_Tot  Perco_mm_Tot               FECHA MES  SEG  DIA  MIN  \
# 0  ...             0.0             0 2018-05-11 20:10:00   5    0   11   10
# 1  ...             0.0             0 2018-05-11 20:20:00   5    0   11   20
# 2  ...             0.0             0 2018-05-11 20:30:00   5    0   11   30
# 3  ...             0.0             0 2018-05-11 20:40:00   5    0   11   40
# 4  ...             0.0             0 2018-05-11 20:50:00   5    0   11   50
#
#    HORA   AÑO   TEMP
# 0    20  2018  23.50
# 1    20  2018  22.96
# 2    20  2018  22.73
# 3    20  2018  22.40
# 4    20  2018  22.46
#
# [5 rows x 43 columns]

# %%
#hacer
df3=df[["FECHA","SEG","MIN","HORA","DIA","MES","AÑO","TEMP"]]

# %%
df3=df3.loc[df['FECHA']>='2018-11-01 00:00:00']

# %%
df3['TPROM']=df3.groupby(['AÑO','MES','DIA','HORA'])['TEMP'].transform('mean')

# %%
df3 = df3[df3["MIN"]==0]

# %%
df3.reset_index(inplace=True)
#df3=df3.drop(df3['level_0','index'])
df3.head()
# Out:
#    index               FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP     TPROM
# 0  24935 2018-11-01 00:00:00    0    0     0    1   11  2018  9.130  8.708333
# 1  24941 2018-11-01 01:00:00    0    0     1    1   11  2018  8.560  8.493333
# 2  24947 2018-11-01 02:00:00    0    0     2    1   11  2018  8.830  8.690000
# 3  24953 2018-11-01 03:00:00    0    0     3    1   11  2018  9.130  8.846667
# 4  24959 2018-11-01 04:00:00    0    0     4    1   11  2018  7.924  7.397500

# %%
UF24=[]
count1=0
for i in range(0,len(df3.TPROM)):
    if(df3["TPROM"][i]<=1.5):
        count1=0     
    elif(df3["TPROM"][i]>1.5 and df3["TPROM"][i]<=2.5):
        count1=0.5
    elif(df3["TPROM"][i]>2.5 and  df3["TPROM"][i]<=9.2):
        count1=1.0
    elif(df3["TPROM"][i]>9.2 and df3["TPROM"][i]<=12.5):
        count1=0.5
    elif(df3["TPROM"][i]>12.5 and df3["TPROM"][i]<=16):
        count1=0
    elif(df3["TPROM"][i]>16.0 and df3["TPROM"][i]<=18.0):
        count1=-0.5
    elif(df3["TPROM"][i]>18):
        count1=-1
        
    UF24.append(count1)
    count1=0

df3['UFH'] =UF24    
df3.head()
# Out:
#    index               FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP     TPROM  \
# 0  24935 2018-11-01 00:00:00    0    0     0    1   11  2018  9.130  8.708333
# 1  24941 2018-11-01 01:00:00    0    0     1    1   11  2018  8.560  8.493333
# 2  24947 2018-11-01 02:00:00    0    0     2    1   11  2018  8.830  8.690000
# 3  24953 2018-11-01 03:00:00    0    0     3    1   11  2018  9.130  8.846667
# 4  24959 2018-11-01 04:00:00    0    0     4    1   11  2018  7.924  7.397500
#
#    UFH
# 0  1.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %%
df3['UFD'] = df3.groupby(['AÑO','MES','DIA'])['UFH'].transform('sum')
df3.head()
# Out:
#    index               FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP     TPROM  \
# 0  24935 2018-11-01 00:00:00    0    0     0    1   11  2018  9.130  8.708333
# 1  24941 2018-11-01 01:00:00    0    0     1    1   11  2018  8.560  8.493333
# 2  24947 2018-11-01 02:00:00    0    0     2    1   11  2018  8.830  8.690000
# 3  24953 2018-11-01 03:00:00    0    0     3    1   11  2018  9.130  8.846667
# 4  24959 2018-11-01 04:00:00    0    0     4    1   11  2018  7.924  7.397500
#
#    UFH  UFD
# 0  1.0 -0.5
# 1  1.0 -0.5
# 2  1.0 -0.5
# 3  1.0 -0.5
# 4  1.0 -0.5

# %%
HF = []
HC = []

for i in range(df3["AÑO"][0],df3["AÑO"][len(df3)-1]+1):
    dfnen = df3[df3["AÑO"] == i]
    for j in range(dfnen["MES"][dfnen.index[0]],dfnen["MES"][dfnen.index[len(dfnen)-1]]+1):
        dfmes = dfnen[dfnen["MES"] == j]
        for k in range(dfmes["DIA"][dfmes.index[0]],dfmes["DIA"][dfmes.index[len(dfmes)-1]]+1):
            dfdia = dfmes[dfmes["DIA"] == k]
            for n in dfdia.index:
                if(0 < dfdia["TPROM"][n] <= 10):
                    HF.append(1)
                    HC.append(0)
                elif(dfdia["TPROM"][n] > 25):
                    HF.append(0)
                    HC.append(1)
                else:
                    HF.append(0)
                    HC.append(0)

# %%
df3["HF"] = HF
df3["HC"] = HC

# %%
df3.head()
# Out:
#    index               FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP     TPROM  \
# 0  24935 2018-11-01 00:00:00    0    0     0    1   11  2018  9.130  8.708333
# 1  24941 2018-11-01 01:00:00    0    0     1    1   11  2018  8.560  8.493333
# 2  24947 2018-11-01 02:00:00    0    0     2    1   11  2018  8.830  8.690000
# 3  24953 2018-11-01 03:00:00    0    0     3    1   11  2018  9.130  8.846667
# 4  24959 2018-11-01 04:00:00    0    0     4    1   11  2018  7.924  7.397500
#
#    UFH  UFD  HF  HC
# 0  1.0 -0.5   1   0
# 1  1.0 -0.5   1   0
# 2  1.0 -0.5   1   0
# 3  1.0 -0.5   1   0
# 4  1.0 -0.5   1   0

# %%
df3["HF24"] = df3.groupby(["AÑO","MES","DIA"])["HF"].transform("sum")
df3["T>25"] = df3.groupby(["AÑO","MES","DIA"])["HC"].transform("sum")
df3["HFE"] = df3["HF24"] - df3["T>25"]

# %%
df3.head()
# Out:
#    index               FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP     TPROM  \
# 0  24935 2018-11-01 00:00:00    0    0     0    1   11  2018  9.130  8.708333
# 1  24941 2018-11-01 01:00:00    0    0     1    1   11  2018  8.560  8.493333
# 2  24947 2018-11-01 02:00:00    0    0     2    1   11  2018  8.830  8.690000
# 3  24953 2018-11-01 03:00:00    0    0     3    1   11  2018  9.130  8.846667
# 4  24959 2018-11-01 04:00:00    0    0     4    1   11  2018  7.924  7.397500
#
#    UFH  UFD  HF  HC  HF24  T>25  HFE
# 0  1.0 -0.5   1   0     8     6    2
# 1  1.0 -0.5   1   0     8     6    2
# 2  1.0 -0.5   1   0     8     6    2
# 3  1.0 -0.5   1   0     8     6    2
# 4  1.0 -0.5   1   0     8     6    2

# %%
df4=df3[df3["HORA"]==0]

# %%
df4.reset_index(inplace=True)
df4.head()
# Out:
#    level_0  index      FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP  \
# 0        0  24935 2018-11-01    0    0     0    1   11  2018   9.13
# 1       24  25079 2018-11-02    0    0     0    2   11  2018  10.79
# 2       48  25223 2018-11-03    0    0     0    3   11  2018  12.85
# 3       72  25367 2018-11-04    0    0     0    4   11  2018  13.14
# 4       96  25511 2018-11-05    0    0     0    5   11  2018  14.41
#
#        TPROM  UFH   UFD  HF  HC  HF24  T>25  HFE
# 0   8.708333  1.0  -0.5   1   0     8     6    2
# 1  10.556667  0.5  -9.0   0   0     0     8   -8
# 2  12.470000  0.5  -9.0   0   0     0     8   -8
# 3  12.733333  0.0 -11.5   0   0     0     8   -8
# 4  13.950000  0.0  -8.0   0   0     0     8   -8

# %%
df4=df4.drop(['index'],axis=1)

# %%
df4.head()
# Out:
#    level_0      FECHA  SEG  MIN  HORA  DIA  MES   AÑO   TEMP      TPROM  UFH  \
# 0        0 2018-11-01    0    0     0    1   11  2018   9.13   8.708333  1.0
# 1       24 2018-11-02    0    0     0    2   11  2018  10.79  10.556667  0.5
# 2       48 2018-11-03    0    0     0    3   11  2018  12.85  12.470000  0.5
# 3       72 2018-11-04    0    0     0    4   11  2018  13.14  12.733333  0.0
# 4       96 2018-11-05    0    0     0    5   11  2018  14.41  13.950000  0.0
#
#     UFD  HF  HC  HF24  T>25  HFE
# 0  -0.5   1   0     8     6    2
# 1  -9.0   0   0     0     8   -8
# 2  -9.0   0   0     0     8   -8
# 3 -11.5   0   0     0     8   -8
# 4  -8.0   0   0     0     8   -8

# %%
# Gráfica de Temperatura y Humedad Relativa
df5 = df4[['HF24','HFE']]
plt.figure(); df5.plot(); plt.legend(loc='best')
plt.title("Comparación de la HF24 y HFE")
plt.ylabel("")
plt.grid(True)
plt.show()
